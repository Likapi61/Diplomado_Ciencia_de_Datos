# %% [markdown]
# **Elecciones de prueba**

# %%
import pandas as pd

# %%
import pandas as pd
Bolivar =pd.read_excel("BolOct2022.xlsx")
display(Bolivar)
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 0             1             BOLIVAR        CARTAGENA
# 1             2             BOLIVAR        CARTAGENA
# 2             3             BOLIVAR        CARTAGENA
# 3             4             BOLIVAR        CARTAGENA
# 4             5             BOLIVAR        CARTAGENA
# ..          ...                 ...              ...
# 602         603             BOLIVAR       VILLANUEVA
# 603         604             BOLIVAR       VILLANUEVA
# 604         605             BOLIVAR         ZAMBRANO
# 605         606             BOLIVAR         ZAMBRANO
# 606         607             BOLIVAR         ZAMBRANO
#
#                     Localidad o Zona                      Nombre Puesto  \
# 0    01LOC. 1 HISTORICA Y DEL CARIBE        CENTRO COMERCIAL BOCAGRANDE
# 1    01LOC. 1 HISTORICA Y DEL CARIBE     UNIV. TECNOLG. DE BOLIVAR - MA
# 2    01LOC. 1 HISTORICA Y DEL CARIBE         LUDOTECA PARQUE CENTENARIO
# ...

# %%
Bolivar.head(5) #por defecto salen 5 primeros
# Out:
#    Cód Puesto Nombre Departamento Nombre Municipio  \
# 0           1             BOLIVAR        CARTAGENA
# 1           2             BOLIVAR        CARTAGENA
# 2           3             BOLIVAR        CARTAGENA
# 3           4             BOLIVAR        CARTAGENA
# 4           5             BOLIVAR        CARTAGENA
#
#                   Localidad o Zona                      Nombre Puesto  \
# 0  01LOC. 1 HISTORICA Y DEL CARIBE        CENTRO COMERCIAL BOCAGRANDE
# 1  01LOC. 1 HISTORICA Y DEL CARIBE     UNIV. TECNOLG. DE BOLIVAR - MA
# 2  01LOC. 1 HISTORICA Y DEL CARIBE         LUDOTECA PARQUE CENTENARIO
# 3  01LOC. 1 HISTORICA Y DEL CARIBE   COL. EUCARÍSTICO DE SANTA TERESA
# 4  01LOC. 1 HISTORICA Y DEL CARIBE  CENTRO COMERCIAL PLAZA BOCAGRANDE
#
#                                    Direccion  GUSTAVO PETRO  \
# 0     CR 2 NO 8-146 BOCAGRANDE AV SAN MARTIN            944
# 1      CLL DEL BOUQUET CR 21 NO. 25-92 MANGA           1575
# ...

# %%
Bolivar.head(30) # por instrucción salen los 30 primeros
# Out:
#     Cód Puesto Nombre Departamento Nombre Municipio  \
# 0            1             BOLIVAR        CARTAGENA
# 1            2             BOLIVAR        CARTAGENA
# 2            3             BOLIVAR        CARTAGENA
# 3            4             BOLIVAR        CARTAGENA
# 4            5             BOLIVAR        CARTAGENA
# 5            6             BOLIVAR        CARTAGENA
# 6            7             BOLIVAR        CARTAGENA
# 7            8             BOLIVAR        CARTAGENA
# 8            9             BOLIVAR        CARTAGENA
# 9           10             BOLIVAR        CARTAGENA
# 10          11             BOLIVAR        CARTAGENA
# 11          12             BOLIVAR        CARTAGENA
# 12          13             BOLIVAR        CARTAGENA
# 13          14             BOLIVAR        CARTAGENA
# 14          15             BOLIVAR        CARTAGENA
# 15          16             BOLIVAR        CARTAGENA
# 16          17             BOLIVAR        CARTAGENA
# ...

# %%
Bolivar.tail(12) # por instrucción salen los 12 ultimos
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 595         596             BOLIVAR          TURBACO
# 596         597             BOLIVAR          TURBACO
# 597         598             BOLIVAR          TURBACO
# 598         599             BOLIVAR          TURBANA
# 599         600             BOLIVAR          TURBANA
# 600         601             BOLIVAR          TURBANA
# 601         602             BOLIVAR       VILLANUEVA
# 602         603             BOLIVAR       VILLANUEVA
# 603         604             BOLIVAR       VILLANUEVA
# 604         605             BOLIVAR         ZAMBRANO
# 605         606             BOLIVAR         ZAMBRANO
# 606         607             BOLIVAR         ZAMBRANO
#
#                    Localidad o Zona              Nombre Puesto  \
# 595               CARCEL DE TURBACO          CARCEL DE TURBACO
# 596      07 CORREGIMIENTO CAÑAVERAL                  CAÑAVERAL
# 597  08 CORREG SAN JOSE DE CHIQUITO                   CHIQUITO
# ...

# %%
Bolivar.info()
print("\n")
display("La forma de la base de datos es:",Bolivar.shape)  #shape:forma de un array
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Cód Puesto              607 non-null    int64
#  1   Nombre Departamento     607 non-null    object
#  2   Nombre Municipio        607 non-null    object
#  3   Localidad o Zona        607 non-null    object
#  4   Nombre Puesto           607 non-null    object
#  5   Direccion               607 non-null    object
#  6   GUSTAVO PETRO           607 non-null    int64
#  7   RODOLFO HERNÁNDEZ       607 non-null    int64
#  8   FEDERICO GUTIÉRREZ      607 non-null    int64
#  9   SERGIO FAJARDO          607 non-null    int64
#  10  JOHN MILTON RODRÍGUEZ   607 non-null    int64
#  11  ENRIQUE GÓMEZ MARTÍNEZ  607 non-null    int64
#  12  INGRID BETANCOURT       607 non-null    int64
#  13  LUIS PÉREZ              607 non-null    int64
# ...

# %%
Bolivar.dtypes #tipo de objeto en cada columna
print("\n")
print(Bolivar.describe())
print("\n")
display(Bolivar.describe(include="all")) #summary, si no se pone el include solo aparece de las variables numéricas
# Out:
#        Cód Puesto  GUSTAVO PETRO  RODOLFO HERNÁNDEZ  FEDERICO GUTIÉRREZ  \
# count  607.000000     607.000000         607.000000          607.000000
# mean   304.000000     592.410214         180.222405          336.172982
# std    175.370085     962.206877         398.700879          512.882421
# min      1.000000       1.000000           0.000000            0.000000
# 25%    152.500000      42.000000          21.000000           48.500000
# 50%    304.000000     125.000000          55.000000          143.000000
# 75%    455.500000     741.000000         218.500000          389.000000
# max    607.000000    6109.000000        7207.000000         4827.000000
#
#        SERGIO FAJARDO  JOHN MILTON RODRÍGUEZ  ENRIQUE GÓMEZ MARTÍNEZ  \
# count      607.000000             607.000000              607.000000
# mean        30.373970              22.365733                2.504119
# std         54.749717              40.994743                3.919095
# ...

# %%
Bolivar.columns
# Out:
# Index(['Cód Puesto', 'Nombre Departamento', 'Nombre Municipio',
#        'Localidad o Zona', 'Nombre Puesto', 'Direccion', 'GUSTAVO PETRO',
#        'RODOLFO HERNÁNDEZ', 'FEDERICO GUTIÉRREZ', 'SERGIO FAJARDO',
#        'JOHN MILTON RODRÍGUEZ', 'ENRIQUE GÓMEZ MARTÍNEZ', 'INGRID BETANCOURT',
#        'LUIS PÉREZ', 'VOTOS EN BLANCO', 'VOTOS NO MARCADOS', 'VOTOS NULOS',
#        'Total Resultado'],
#       dtype='object')

# %%
VOTOSNULOS = Bolivar["VOTOS NULOS"]
VOTOSNULOS
# Out:
# 0       7
# 1      10
# 2       5
# 3       5
# 4       0
#        ..
# 602     5
# 603     1
# 604    42
# 605     2
# 606     3
# Name: VOTOS NULOS, Length: 607, dtype: int64

# %%
print(Bolivar.iloc[0:1,])
print(type(Bolivar.iloc[0:1,]))
# Out:
#    Cód Puesto Nombre Departamento Nombre Municipio  \
# 0           1             BOLIVAR        CARTAGENA
#
#                   Localidad o Zona                Nombre Puesto  \
# 0  01LOC. 1 HISTORICA Y DEL CARIBE  CENTRO COMERCIAL BOCAGRANDE
#
#                                 Direccion  GUSTAVO PETRO  RODOLFO HERNÁNDEZ  \
# 0  CR 2 NO 8-146 BOCAGRANDE AV SAN MARTIN            944                506
#
#    FEDERICO GUTIÉRREZ  SERGIO FAJARDO  JOHN MILTON RODRÍGUEZ  \
# 0                4827             330                     28
#
#    ENRIQUE GÓMEZ MARTÍNEZ  INGRID BETANCOURT  LUIS PÉREZ  VOTOS EN BLANCO  \
# 0                      19                  0           0               39
#
#    VOTOS NO MARCADOS  VOTOS NULOS  Total Resultado
# 0                  8            7             6708
# <class 'pandas.core.frame.DataFrame'>

# %%
display(Bolivar.iloc[118:122,1:4]) # Los de Bolivar desde el 118 al 122 (este es excluyente)
# Out:
#     Nombre Departamento Nombre Municipio                 Localidad o Zona
# 118             BOLIVAR        CARTAGENA  02LOC. 2  LA VIRGEN Y TURISTICA
# 119             BOLIVAR        CARTAGENA  02LOC. 2  LA VIRGEN Y TURISTICA
# 120             BOLIVAR             ACHI        PUESTO CABECERA MUNICIPAL
# 121             BOLIVAR             ACHI                           BOYACA

# %%
Bolivar.tail() # Los de Bolivar finales,por defecto arroja 5
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 602         603             BOLIVAR       VILLANUEVA
# 603         604             BOLIVAR       VILLANUEVA
# 604         605             BOLIVAR         ZAMBRANO
# 605         606             BOLIVAR         ZAMBRANO
# 606         607             BOLIVAR         ZAMBRANO
#
#               Localidad o Zona              Nombre Puesto  \
# 602          DCI ZIPAQUILANDIA          DCI ZIPAQUILANDIA
# 603                  ALGARROBO                  ALGARROBO
# 604  PUESTO CABECERA MUNICIPAL  PUESTO CABECERA MUNICIPAL
# 605              JESUS DEL RIO              JESUS DEL RIO
# 606              VEREDA CAPACA              VEREDA CAPACA
#
#                                              Direccion  GUSTAVO PETRO  \
# 602                               PLAZA PRINCIPAL KM 9            220
# 603                              PLAZA PRINCIPAL KM 12             24
# 604                   CLL 12 N° 12-78 BARRIO EL AMPARO           3198
# ...

# %%
Bolivar["Total Resultado"] > 2000 #Verdadero o falso si cumple la condición
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 602    False
# 603    False
# 604     True
# 605    False
# 606    False
# Name: Total Resultado, Length: 607, dtype: bool

# %%
codsat1000 = Bolivar[Bolivar["Total Resultado"] > 1000] # Llama aquellos cuyo valor es verdadero
codsat1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 604
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Cód Puesto              187 non-null    int64
#  1   Nombre Departamento     187 non-null    object
#  2   Nombre Municipio        187 non-null    object
#  3   Localidad o Zona        187 non-null    object
#  4   Nombre Puesto           187 non-null    object
#  5   Direccion               187 non-null    object
#  6   GUSTAVO PETRO           187 non-null    int64
#  7   RODOLFO HERNÁNDEZ       187 non-null    int64
#  8   FEDERICO GUTIÉRREZ      187 non-null    int64
#  9   SERGIO FAJARDO          187 non-null    int64
#  10  JOHN MILTON RODRÍGUEZ   187 non-null    int64
#  11  ENRIQUE GÓMEZ MARTÍNEZ  187 non-null    int64
#  12  INGRID BETANCOURT       187 non-null    int64
#  13  LUIS PÉREZ              187 non-null    int64
# ...

# %%
no_na = Bolivar[Bolivar["VOTOS NULOS"].notna()]
print(no_na.shape)
print(Bolivar.shape)
# Out:
# (607, 18)
# (607, 18)

# %%
codcou1 = Bolivar[Bolivar["Nombre Municipio"].isin(["TURBACO"])]
codcou1
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 583         584             BOLIVAR          TURBACO
# 584         585             BOLIVAR          TURBACO
# 585         586             BOLIVAR          TURBACO
# 586         587             BOLIVAR          TURBACO
# 587         588             BOLIVAR          TURBACO
# 588         589             BOLIVAR          TURBACO
# 589         590             BOLIVAR          TURBACO
# 590         591             BOLIVAR          TURBACO
# 591         592             BOLIVAR          TURBACO
# 592         593             BOLIVAR          TURBACO
# 593         594             BOLIVAR          TURBACO
# 594         595             BOLIVAR          TURBACO
# 595         596             BOLIVAR          TURBACO
# 596         597             BOLIVAR          TURBACO
# 597         598             BOLIVAR          TURBACO
#
#                            Localidad o Zona  \
# 583                              01COMUNA 1
# ...

# %%
codcou2 = Bolivar.loc[:, 'Nombre Municipio'] == "ACHI"
codcou2_ = Bolivar.loc[codcou2]
codcou2_
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 120         121             BOLIVAR             ACHI
# 121         122             BOLIVAR             ACHI
# 122         123             BOLIVAR             ACHI
# 123         124             BOLIVAR             ACHI
# 124         125             BOLIVAR             ACHI
# 125         126             BOLIVAR             ACHI
# 126         127             BOLIVAR             ACHI
# 127         128             BOLIVAR             ACHI
# 128         129             BOLIVAR             ACHI
# 129         130             BOLIVAR             ACHI
# 130         131             BOLIVAR             ACHI
# 131         132             BOLIVAR             ACHI
# 132         133             BOLIVAR             ACHI
# 133         134             BOLIVAR             ACHI
# 134         135             BOLIVAR             ACHI
# 135         136             BOLIVAR             ACHI
# 136         137             BOLIVAR             ACHI
# ...

# %%
Bolivar[(Bolivar["Nombre Municipio"] == "ARJONA") | (Bolivar["Nombre Municipio"] == "ZAMBRANO")]
# Out:
#      Cód Puesto Nombre Departamento Nombre Municipio  \
# 153         154             BOLIVAR           ARJONA
# 154         155             BOLIVAR           ARJONA
# 155         156             BOLIVAR           ARJONA
# 156         157             BOLIVAR           ARJONA
# 157         158             BOLIVAR           ARJONA
# 158         159             BOLIVAR           ARJONA
# 159         160             BOLIVAR           ARJONA
# 160         161             BOLIVAR           ARJONA
# 161         162             BOLIVAR           ARJONA
# 162         163             BOLIVAR           ARJONA
# 163         164             BOLIVAR           ARJONA
# 164         165             BOLIVAR           ARJONA
# 604         605             BOLIVAR         ZAMBRANO
# 605         606             BOLIVAR         ZAMBRANO
# 606         607             BOLIVAR         ZAMBRANO
#
#                      Localidad o Zona                       Nombre Puesto  \
# ...

# %%
Bolivar[(Bolivar["Nombre Municipio"] == "ARJONA") & (Bolivar["VOTOS NULOS"] >=10)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 153 to 160
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Cód Puesto              7 non-null      int64
#  1   Nombre Departamento     7 non-null      object
#  2   Nombre Municipio        7 non-null      object
#  3   Localidad o Zona        7 non-null      object
#  4   Nombre Puesto           7 non-null      object
#  5   Direccion               7 non-null      object
#  6   GUSTAVO PETRO           7 non-null      int64
#  7   RODOLFO HERNÁNDEZ       7 non-null      int64
#  8   FEDERICO GUTIÉRREZ      7 non-null      int64
#  9   SERGIO FAJARDO          7 non-null      int64
#  10  JOHN MILTON RODRÍGUEZ   7 non-null      int64
#  11  ENRIQUE GÓMEZ MARTÍNEZ  7 non-null      int64
#  12  INGRID BETANCOURT       7 non-null      int64
#  13  LUIS PÉREZ              7 non-null      int64
# ...
